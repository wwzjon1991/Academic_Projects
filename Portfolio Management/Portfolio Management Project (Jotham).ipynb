# %% [markdown]
# # Portfolio Management
#
# ###   Group Members:
#
# 1. Song Lu<br/>
# 2. Padey Tan<br/>
# 3. Jotham Teo<br/>
# 4. Donovan Khoo<br/>
# 5. Jonathan Wee<br/>
#
#
# **Objective:** In this project, we aim to build stylized long-short equity factor mimicking portfolios using different fundamental variables from Ken French’s data library and explore empirically their univariate efficacy over time and across different size segments. We then go on to build multi-factor strategies using alternative weighting schemes and compare them to the static equally weighted multi-factor strategy. Two alternative top-down factor weighting schemes will be considered:
# 1. Equal risk contribution across factors
# 2. Weighting based on factor persistence
#
# **Data:** Attached with the project description are 6 csv files containing the monthly time series of value- and equal-weighted returns for portfolios formed on size and different fundamental variables consisting of **book-to-price, cashflow-to-price, dividend yield, investment, profitability, prior 1-month return and 12-1 price momentum**. In addition, there is a csv file named “F-F_Research_Data_Factors” which houses the Fama-French 3 factor model returns.

# %%
import numpy as np
import pandas as pd
import datetime as dt
from scipy.optimize import minimize

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Book-to-price ratio - Value-weighted & equal-weighted portfolios
value_bp = pd.read_csv('6_Portfolios_ME_BP_2x3.csv', skiprows=15, nrows=1101, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
equal_bp = pd.read_csv('6_Portfolios_ME_BP_2x3.csv', skiprows=1120, nrows=1101, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))

# Cashflow-to-price - Value-weighted & equal-weighted portfolios
value_cfp = pd.read_csv('6_Portfolios_ME_CFP_2x3.csv', skiprows=19, nrows=801, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
equal_cfp = pd.read_csv('6_Portfolios_ME_CFP_2x3.csv', skiprows=824, nrows=801, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))

# Dividend Yield - Value-weighted & equal-weighted portfolios
value_dp = pd.read_csv('6_Portfolios_ME_DP_2x3.csv', skiprows=19, nrows=1089, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
equal_dp = pd.read_csv('6_Portfolios_ME_DP_2x3.csv', skiprows=1112, nrows=1089, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))

# Profitability - Value-weighted & equal-weighted portfolios
value_pro = pd.read_csv('6_Portfolios_ME_OP_2x3.csv', skiprows=16, nrows=657, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
equal_pro = pd.read_csv('6_Portfolios_ME_OP_2x3.csv', skiprows=677, nrows=657, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))

# 12-1 price momentum - Value-weighted & equal-weighted portfolios
value_mo = pd.read_csv('6_Portfolios_ME_Prior_12_2.csv', skiprows=11, nrows=1095, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
equal_mo = pd.read_csv('6_Portfolios_ME_Prior_12_2.csv', skiprows=1110, nrows=1095, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))

# %%
# Note: lambda function reorders columns of the following dataframes so that lo minus hi is carried out. This is simply for ease.
reorder = lambda x: x[[x.columns[2],x.columns[1],x.columns[0],x.columns[5],x.columns[4],x.columns[3]]]

# Investment - Value-weighted & equal-weighted portfolios
value_inv = pd.read_csv('6_Portfolios_ME_INV_2x3.csv', skiprows=16, nrows=657, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
equal_inv = pd.read_csv('6_Portfolios_ME_INV_2x3.csv', skiprows=677, nrows=657, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
value_inv, equal_inv = reorder(value_inv), reorder(equal_inv)

# Prior 1-month return - Value-weighted & equal-weighted portfolios
value_prior = pd.read_csv('6_Portfolios_ME_Prior_1_0.csv', skiprows=11, nrows=1106, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
equal_prior = pd.read_csv('6_Portfolios_ME_Prior_1_0.csv', skiprows=1121, nrows=1106, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))
value_prior, equal_prior = reorder(value_prior), reorder(equal_prior)

# fama french data factors
ff = pd.read_csv('F-F_Research_Data_Factors.csv', skiprows=3, nrows=1101, parse_dates=True, index_col=0, date_parser=lambda x:pd.to_datetime(x, format='%Y%m'))

# %%
# synchronizing every time series to start at the same date (the time series with the latest start date)
value_weight = [value_bp, value_cfp, value_dp, value_inv, value_pro, value_prior, value_mo]
latest_start_val = max([value_weight[i].index[0] for i in range(7)]) # find the time series with the latest date
value_weight = [value_weight[i][value_weight[i].index.get_loc(latest_start_val):] for i in range(7)]

equal_weight = [equal_bp, equal_cfp, equal_dp, equal_inv, equal_pro, equal_prior, equal_mo]
latest_start_eq = max([value_weight[i].index[0] for i in range(7)]) # find the time series with the latest date
equal_weight = [equal_weight[i][equal_weight[i].index.get_loc(latest_start_eq):] for i in range(7)]

fundamental_title = ['Book-to-Price', 'Cash-to-Price', 'Dividend Yield', 'Investment', 'Profitability', 'Prior Month Return', '12-1 Momentum']

# %% [markdown]
# ### Task 1:
# a) For each of the six fundamental variables, construct long-short factor mimicking portfolios and plot their historical performance across different size segments. <br>

# %%
# %matplotlib inline
# hi minus lo except for Investment & Prior month return - lo minus hi
f = lambda x, y: (x - y).cumsum() # cumulative sum
sns.set_context('talk')

def long_short(x,y,title):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    time_series_1 = pd.DataFrame({'Big Cap': f(x.iloc[:,5],x.iloc[:,3]), 'Small Cap': f(x.iloc[:,2],x.iloc[:,0])}) # low minus high
    time_series_2 = pd.DataFrame({'Big Cap': f(y.iloc[:,5],y.iloc[:,3]), 'Small Cap': f(y.iloc[:,2],y.iloc[:,0])})
    time_series_1.plot(ax=axs[0], title=title + ' - Value-weighted')
    time_series_2.plot(ax=axs[1], title=title + ' - Equal-weighted')  
    return plt.show()

[long_short(value_weight[i],equal_weight[i],fundamental_title[i]) for i in range(7)]
# Out:
# [None, None, None, None, None, None, None]

# %% [markdown]
# <font color='blue'><b>Comments:</b>
# RMWt is the difference between the returns on diversified portfolios of stocks with robust and weak profitability, and CMAt is the difference between the returns on diversified portfolios of low and high investment stocks (Fama, French 2014)</font>

# %% [markdown]
# b) Taking the market return from Fama-French’s 3-factor model, calculate and plot the rolling 3-year market beta for these stylized portfolios. <br>

# %%
import statsmodels.api as sm

# note, this regression carries out a rolling window of 3 years
def regress(dataframe):
    
    # for the sake of not changing original dataframe
    df = dataframe 
    french = ff
    
    # to verify longer dataframe & match range of dates
    if len(ff) > len(df):
        french = ff[(ff.index >= df.index[0])]
    else:
        df = df[(df.index >= ff.index[0])]
    
    # after range of dates are equal, regression is carried out
    excess_ret = sm.add_constant(french['Mkt-RF'])
    small_hi_alpha, small_lo_alpha, big_hi_alpha, big_lo_alpha  = [], [], [], []
    small_hi_beta, small_lo_beta, big_hi_beta, big_lo_beta = [], [], [], []
    
    # returns minus risk-free rate, thereafter regression is run in a 3-year rolling window
    for i in np.arange(0,len(df)+1,1):
        small_hi, small_lo, big_hi, big_lo = df.iloc[:,2][i:i+36] - french.iloc[:,3][i:i+36], \
        df.iloc[:,0][i:i+36] - french.iloc[:,3][i:i+36], df.iloc[:,5][i:i+36] - french.iloc[:,3][i:i+36], \
        df.iloc[:,3][i:i+36] - french.iloc[:,3][i:i+36]
        
        # small cap hi
        if len(small_hi) == 36: #ensuring that range is 36 months
            est_1 = sm.OLS(small_hi, excess_ret[i:i+36]).fit()
            small_hi_alpha.append(est_1.params[0]); small_hi_beta.append(est_1.params[1])
        # small cap lo
        if len(small_lo) == 36: #ensuring that range is 36 months
            est_2 = sm.OLS(small_lo, excess_ret[i:i+36]).fit()
            small_lo_alpha.append(est_2.params[0]); small_lo_beta.append(est_2.params[1])
        # big cap hi
        if len(big_hi) == 36: #ensuring that range is 36 months
            est_3 = sm.OLS(big_hi, excess_ret[i:i+36]).fit()
            big_hi_alpha.append(est_3.params[0]); big_hi_beta.append(est_3.params[1])
        # big cap lo
        if len(big_lo) == 36: #ensuring that range is 36 months
            est_4 = sm.OLS(big_lo, excess_ret[i:i+36]).fit()
            big_lo_alpha.append(est_4.params[0]); big_lo_beta.append(est_4.params[1])
            
    table = pd.DataFrame({'small_hi_alpha': small_hi_alpha, 'small_lo_alpha': small_lo_alpha,\
                          'big_hi_alpha': big_hi_alpha, 'big_lo_alpha': big_lo_alpha,\
                          'small_hi_beta': small_hi_beta, 'small_lo_beta': small_lo_beta,\
                          'big_hi_beta': big_hi_beta, 'big_lo_beta': big_lo_beta,'date': df.iloc[:,0][35:len(df)]})
    
    return table.drop(columns=['date'])

# %%
# function to plot out market betas
def mkt_beta(value,equal,title):
    value_coef, equal_coef = regress(value), regress(equal) # running function regress
    value_beta, equal_beta = pd.DataFrame({'beta_small': value_coef['small_hi_beta'] - value_coef['small_lo_beta'], 
                                           'beta_big': value_coef['big_hi_beta'] - value_coef['big_lo_beta']}), \
    pd.DataFrame({'beta_small': equal_coef['small_hi_beta'] - equal_coef['small_lo_beta'], 
                                           'beta_big': equal_coef['big_hi_beta'] - equal_coef['big_lo_beta']})
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    value_beta[['beta_small', 'beta_big']].plot(ax=axs[0], title=title + ' - Value-weighted')
    equal_beta[['beta_small', 'beta_big']].plot(ax=axs[1], title=title + ' - Equal-weighted')
    return plt.show()

# %%
# subplots
[mkt_beta(value_weight[i],equal_weight[i],fundamental_title[i]) for i in range(7)]
# Out:
# [None, None, None, None, None, None, None]

# %% [markdown]
# c) Considering both size segments, construct a beta-neutral factor mimicking portfolio for each fundamental variable. Comment on your results.

# %%
# Visit cvxpy.org, install cvxpy with conda:
# conda install -c conda-forge lapack
# conda install -c cvxgrp cvxpy

import cvxpy as cvx
from cvxpy import *

# %%
def optimize(df):
    
    w_big_lo, w_small_lo, w_big_hi, w_small_hi = [], [], [], []
    agg_alpha = []
    status = []
    lambd = 0.1 # cash reserve as a proportion of shorting stocks
    
    for i in np.arange(0,len(df),1): # len(df)-1
        
        # cvx variables of individual weights
        p1 = cvx.Variable() # short big cap lo weight
        p2 = cvx.Variable() # short small cap lo weight
        p3 = cvx.Variable() # long big cap hi weight
        p4 = cvx.Variable() # long small cap hi weight
        
        # sum of weight * beta = 0, p3 + p4 - 0.1*(p1 + p2) == 1
        constraints = [p1 <= 0, p2 <= 0, p3 >= 0, p4 >= 0,\
                       sum([p3*df['big_hi_beta'][i], p4*df['small_hi_beta'][i], \
                            p1*df['big_lo_beta'][i], p2*df['small_lo_beta'][i]]) == 0,\
                       p3 + p4 - 0.1*(p1 + p2) == 1] #
        
        obj = cvx.Maximize(sum([p1*df['big_lo_alpha'][i], p2*df['small_lo_alpha'][i], \
                                p3*df['big_hi_alpha'][i], p4*df['small_hi_alpha'][i]]))
        prob = cvx.Problem(obj, constraints)
        prob.solve()  # Returns the optimal value.
        #print("status:", prob.status)
        #print("optimal value", prob.value)
        #print("optimal var", p1.value, p2.value, p3.value, p4.value)
        status.append(prob.status); agg_alpha.append(prob.value); w_big_lo.append(p1.value); \
        w_small_lo.append(p2.value); w_big_hi.append(p3.value); w_small_hi.append(p4.value)
        
    weights_table = pd.DataFrame({'status': status, 'agg_alpha': agg_alpha, 'w_big_lo': w_big_lo, \
                                  'w_small_lo': w_small_lo, 'w_big_hi': w_big_hi, 'w_small_hi': w_small_hi})
    return weights_table

# %%
#ttt = optimize(regress(equal_weight[0]))
#ttt['w_big_hi'] + ttt['w_small_hi'] - 0.1 * ttt['w_big_lo'] - 0.1 *ttt['w_small_lo']

# %%
#uuu = regress(equal_weight[0])
#uuu = uuu.reset_index(drop=True)
#uuu.head()

#ttt['w_big_hi'] * uuu['big_hi_beta']  + ttt['w_small_hi'] * uuu['small_hi_beta']  + ttt['w_big_lo'] * uuu['big_lo_beta'] + \
#ttt['w_small_lo'] * uuu['small_lo_beta']

# %%
def beta_neutral(df):
    betaWghts = optimize(regress(df)) # regressing to get beta coefficients & optimizing to get weights of betas
    # there are issues with multiplying columns of 2 diff dataframes with datetime index, hence datetime is pushed out of index
    readj_df = df.iloc[36:len(df)+1].reset_index()
    
    f = lambda x, y: (x - y).cumsum()

    # beta neutral returns = (beta wt * big_hi + beta wt * small_hi) - (beta wt * big_lo + beta wt * small_lo)
    beta_portfolio = (betaWghts['w_big_hi'] * readj_df.iloc[:,6]) + (betaWghts['w_small_hi'] * readj_df.iloc[:,3]) \
    - (betaWghts['w_big_lo'] * readj_df.iloc[:,4]) - (betaWghts['w_small_lo'] * readj_df.iloc[:,1])

    rf_rate = ff.iloc[:,3][36:len(df)].reset_index()

    betaNeu_vs_ls = pd.DataFrame({'Date': readj_df.iloc[:,0],\
                              'Beta Neutral': f(beta_portfolio,0), \
                              'Big Cap Long-short': f(readj_df.iloc[:,6],readj_df.iloc[:,4]), \
                              'Small Cap Long-short': f(readj_df.iloc[:,3],readj_df.iloc[:,1]),\
                              'Risk-free': f(rf_rate.iloc[:,1],0)})

    betaNeu_vs_ls.set_index('Date', inplace=True)
    
    return betaNeu_vs_ls

# %%
def beta_neutral_plot(equal_weight):
    fig, axs = plt.subplots(4,2,figsize=(15,20))
    fig.delaxes(axs[-1, -1])
    #for i in range(7):
    beta_neutral(equal_weight[0]).plot(ax=axs[0,0], title= fundamental_title[0] + ' - Equal-weighted')
    beta_neutral(equal_weight[1]).plot(ax=axs[0,1], title= fundamental_title[1] + ' - Equal-weighted')
    beta_neutral(equal_weight[2]).plot(ax=axs[1,0], title= fundamental_title[2] + ' - Equal-weighted')
    beta_neutral(equal_weight[3]).plot(ax=axs[1,1], title= fundamental_title[3] + ' - Equal-weighted')
    beta_neutral(equal_weight[4]).plot(ax=axs[2,0], title= fundamental_title[4] + ' - Equal-weighted')
    beta_neutral(equal_weight[5]).plot(ax=axs[2,1], title= fundamental_title[5] + ' - Equal-weighted')
    beta_neutral(equal_weight[6]).plot(ax=axs[3,0], title= fundamental_title[6] + ' - Equal-weighted')
    plt.show()
    #return plt.show()

sns.set_context('talk')
beta_neutral_plot(equal_weight)

# %% [markdown]
# ### Task 2
# a) Calculate the full sample correlation matrix of unadjusted factor returns (i.e. not the beta-neutral version) derived from 1. Comment on your findings.

# %%
# 0.5 * (big_hi + small_hi) - 0.5 * (big_lo + small_lo)
# Average returns on the two high factor portfolios minus the average return on the two low factor portfolios
# except for Investment & Prior Month return (i.e. low minus high)
factor_return = lambda big_hi, small_hi, big_lo, small_lo: 0.5 * (big_hi + small_hi) - 0.5 * (big_lo + small_lo)

dic_val = [factor_return(value_weight[i].iloc[:,5], value_weight[i].iloc[:,2], value_weight[i].iloc[:,3], value_weight[i].iloc[:,0]) for i in range(7)]
dic_eq = [factor_return(equal_weight[i].iloc[:,5], equal_weight[i].iloc[:,2], equal_weight[i].iloc[:,3], equal_weight[i].iloc[:,0]) for i in range(7)]
#zipping labels with respective data into a dictionary with keys & values
corr_val, corr_eq = pd.DataFrame(dict(zip(fundamental_title, dic_val))), pd.DataFrame(dict(zip(fundamental_title, dic_eq)))



def corr_plot(df,title):
    # Generate a mask for the upper triangle
    mask = np.zeros_like(df, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    
    # Set up the matplotlib figure
    plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 20, sep=20, as_cmap=True) # Generate a custom diverging colormap
    sns.heatmap(df, cmap=cmap)
    plt.title('Correlation Matrix of ' + title, fontsize= 20)
    return plt.show()

corr_plot(corr_val.corr(), 'Value Weight')

# %%
corr_val.corr()
# Out:
#                     12-1 Momentum  Book-to-Price  Cash-to-Price  \
# 12-1 Momentum            1.000000      -0.185954      -0.115771
# Book-to-Price           -0.185954       1.000000       0.847593
# Cash-to-Price           -0.115771       0.847593       1.000000
# Dividend Yield          -0.201054       0.668925       0.658368
# Investment              -0.021388       0.688972       0.606040
# Prior Month Return      -0.287986       0.003916      -0.052615
# Profitability            0.109749       0.071422       0.209386
#
#                     Dividend Yield  Investment  Prior Month Return  \
# 12-1 Momentum            -0.201054   -0.021388           -0.287986
# Book-to-Price             0.668925    0.688972            0.003916
# Cash-to-Price             0.658368    0.606040           -0.052615
# Dividend Yield            1.000000    0.606044           -0.087263
# Investment                0.606044    1.000000           -0.121822
# Prior Month Return       -0.087263   -0.121822            1.000000
# Profitability             0.054613   -0.041520           -0.087263
#
#                     Profitability
# 12-1 Momentum            0.109749
# Book-to-Price            0.071422
# Cash-to-Price            0.209386
# Dividend Yield           0.054613
# Investment              -0.041520
# Prior Month Return      -0.087263
# Profitability            1.000000

# %%
corr_plot(corr_eq.corr(), 'Equal Weight')

# %%
corr_eq.corr()
# Out:
#                     12-1 Momentum  Book-to-Price  Cash-to-Price  \
# 12-1 Momentum            1.000000      -0.018718      -0.046817
# Book-to-Price           -0.018718       1.000000       0.862662
# Cash-to-Price           -0.046817       0.862662       1.000000
# Dividend Yield          -0.116451       0.665483       0.608558
# Investment              -0.012310       0.710180       0.579812
# Prior Month Return      -0.383255      -0.162697      -0.117042
# Profitability            0.270657       0.271472       0.248993
#
#                     Dividend Yield  Investment  Prior Month Return  \
# 12-1 Momentum            -0.116451   -0.012310           -0.383255
# Book-to-Price             0.665483    0.710180           -0.162697
# Cash-to-Price             0.608558    0.579812           -0.117042
# Dividend Yield            1.000000    0.556062           -0.165041
# Investment                0.556062    1.000000           -0.152950
# Prior Month Return       -0.165041   -0.152950            1.000000
# Profitability            -0.013074   -0.003086           -0.215088
#
#                     Profitability
# 12-1 Momentum            0.270657
# Book-to-Price            0.271472
# Cash-to-Price            0.248993
# Dividend Yield          -0.013074
# Investment              -0.003086
# Prior Month Return      -0.215088
# Profitability            1.000000

# %% [markdown]
# b) Using a lookback period of 5 years, employ an equal risk contribution factor weighting strategy with monthly rebalancing. The monthly resultant portfolios should be dollar neutral with a long leg exposure of 100%.

# %%
column_names = corr_eq.columns.values # collect names of columns
weights = np.repeat(1/7,7) # equal portfolio weights 1 / 7. Set as matrix.

def risk_budget_objective(weights, cov_df):
    
    w = np.matrix(weights) # set weights to a matrix
    cov_matrix = cov_df.values # set covariance df as a matrix with .values
    portfolio_sig = np.sqrt((w * cov_matrix * w.T)[0,0]) # portfolio risk
    
    mar_risk_contrib = cov_matrix * w.T # marginal risk contribution
    factor_risk_contrib = np.multiply(mar_risk_contrib, w.T)/portfolio_sig  # Risk Contribution
    
    x_t = [1/7] * 7 # your risk budget percent of total portfolio risk (equal risk). list of 1/7
    risk_target = np.asmatrix(np.multiply(portfolio_sig, x_t)) # multiplying equal risk percent with portfolio risk
    
    J = sum(np.square(factor_risk_contrib - risk_target.T))[0,0] # sum of squared error
    
    return J


def erc_weights(weights, cov_df):
    # Restrictions to consider in the optimisation: only long positions whose sum equals 100%
    total_weight_constraint = lambda x: np.sum(x)-1.0 
    long_only_constraint = lambda x: x
    cons = ({'type': 'eq', 'fun': total_weight_constraint}, {'type': 'ineq', 'fun': long_only_constraint})
    res= minimize(risk_budget_objective, weights, cov_df, method='SLSQP',constraints=cons, options={'disp': True})
    return res.x

# %%
df_erc = pd.DataFrame(columns=column_names, index=range(0,len(corr_eq)-59)) # empty dataframe

for i in np.arange(0,len(corr_eq)-59,1):  # 597 rows in dataframe
    if len(corr_eq[i:i+60]) == 60: 
        
        # finding erc weights of each factor. corr_eq[i:i+60].cov() -> covariances of factors from i to i+60
        # weights are in column vector. .T is to convert to row vector
        # np.asarray -> changes matrix to array. np.squeeze -> removes list characteristic & give value
        df_erc.iloc[i] = pd.Series(dict(zip(column_names, \
                                            erc_weights(weights, corr_eq[i:i+60].cov().T) )))
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012044280399753686
#             Iterations: 12
#             Function evaluations: 111
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012344623492349311
#             Iterations: 11
#             Function evaluations: 103
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012493540933950715
#             Iterations: 12
#             Function evaluations: 111
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012476655328754088
#             Iterations: 10
#             Function evaluations: 94
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012732472459389637
#             Iterations: 12
#             Function evaluations: 112
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012651586421231114
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012806718979764653
#             Iterations: 13
#             Function evaluations: 121
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012917111295684808
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.012982021418601745
#             Iterations: 13
#             Function evaluations: 122
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.2789246367779475e-07
#             Iterations: 19
#             Function evaluations: 181
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0622207987962903e-07
#             Iterations: 17
#             Function evaluations: 159
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3974671712736466e-07
#             Iterations: 15
#             Function evaluations: 143
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.942145466158412e-07
#             Iterations: 15
#             Function evaluations: 140
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.9790173415134394e-08
#             Iterations: 15
#             Function evaluations: 142
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.591123325598009e-08
#             Iterations: 19
#             Function evaluations: 179
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.5116378175652164e-07
#             Iterations: 17
#             Function evaluations: 162
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0777299752021263e-07
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.962029235612987e-08
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.9250687989040524e-07
#             Iterations: 11
#             Function evaluations: 103
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.756364650517458e-08
#             Iterations: 11
#             Function evaluations: 103
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.396645399789766e-09
#             Iterations: 14
#             Function evaluations: 131
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.8189356501957465e-07
#             Iterations: 15
#             Function evaluations: 142
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.3630352347607144e-07
#             Iterations: 19
#             Function evaluations: 181
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.5230923110421902e-07
#             Iterations: 16
#             Function evaluations: 152
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.265366278115891e-07
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.6132904930216277e-07
#             Iterations: 15
#             Function evaluations: 142
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.1445553900977755e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2149401929665574e-07
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0129668900787227e-07
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.689941583909307e-08
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.715955551688731e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2913174753463963e-09
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4730398161620444e-07
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.039575386070331e-08
#             Iterations: 12
#             Function evaluations: 117
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2121162521611855e-07
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.325907689266234e-09
#             Iterations: 11
#             Function evaluations: 109
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.4299122683449776e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.3039832466504146e-07
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.696241640454863e-07
#             Iterations: 12
#             Function evaluations: 117
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1901820038247295e-09
#             Iterations: 13
#             Function evaluations: 127
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.119274881115034e-08
#             Iterations: 14
#             Function evaluations: 134
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.1534585376145776e-10
#             Iterations: 13
#             Function evaluations: 126
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.6817982000956313e-08
#             Iterations: 13
#             Function evaluations: 126
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.272687937552686e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.483979760572182e-07
#             Iterations: 12
#             Function evaluations: 117
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.149608447811522e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.3458437152868062e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.6787318567066287e-07
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.789245392619502e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.976206541154323e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0798008355321579e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.337345433706102e-09
#             Iterations: 13
#             Function evaluations: 125
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 8.687289856778424e-08
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.8268267435933594e-07
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1918708780189887e-07
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.623183453267526e-08
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.747888871867682e-07
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3519258564277586e-07
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.9726508428209744e-07
#             Iterations: 13
#             Function evaluations: 125
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.5909438941805636e-07
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.5638321315287005e-08
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.166952280064225e-07
#             Iterations: 13
#             Function evaluations: 123
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3158701161576472e-07
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.419910583145779e-08
#             Iterations: 13
#             Function evaluations: 125
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.787877293650533e-08
#             Iterations: 14
#             Function evaluations: 134
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.13170388869075e-08
#             Iterations: 14
#             Function evaluations: 134
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.8868650803048714e-08
#             Iterations: 16
#             Function evaluations: 153
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.206320209538028e-08
#             Iterations: 18
#             Function evaluations: 172
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.789634046492296e-08
#             Iterations: 18
#             Function evaluations: 172
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.151566189569611e-07
#             Iterations: 18
#             Function evaluations: 172
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3975774629762003e-08
#             Iterations: 21
#             Function evaluations: 200
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.509019523420815e-08
#             Iterations: 20
#             Function evaluations: 192
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.921531639917306e-08
#             Iterations: 22
#             Function evaluations: 210
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.943212272640103e-08
#             Iterations: 16
#             Function evaluations: 152
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.045595695943320136
#             Iterations: 13
#             Function evaluations: 123
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04771943440368789
#             Iterations: 13
#             Function evaluations: 123
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04527415188538758
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.045264870456167394
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.088808604782673e-09
#             Iterations: 16
#             Function evaluations: 156
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.053580890211510857
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.053535610043160195
#             Iterations: 13
#             Function evaluations: 123
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.05310049668466927
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.05438885104654597
#             Iterations: 10
#             Function evaluations: 96
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.05435460266429955
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.052999381131450814
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.05297087361900814
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.05202114051579265
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04434494619155458
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03611076536670606
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03700157222248425
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03706399738531314
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04082676608253248
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03961583551302037
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.038332050348203556
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.038425921282882046
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04033283421931277
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.040036433629654346
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03958936176821345
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03946527265027636
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03969344721857215
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.039567285609755816
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03919677893326713
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0391962560107237
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03947018319032583
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03877135664088413
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03889543688653596
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03877020426589679
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03831935832069123
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03803461892424895
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03811027575723437
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.040068244200160134
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.040176558335599244
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.040285852150224635
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04026818133833411
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04075879476154076
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.04050535330121162
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.040472610565510214
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.040601036210803576
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.039573917192238336
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.03948704515734837
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.038759161168026995
#             Iterations: 14
#             Function evaluations: 133
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.032953596268084556
#             Iterations: 10
#             Function evaluations: 95
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.031796527515240924
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.030961075216601002
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.031672520693961904
#             Iterations: 11
#             Function evaluations: 104
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.031208900828280216
#             Iterations: 9
#             Function evaluations: 87
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.027779287879072044
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.027608466833366496
#             Iterations: 11
#             Function evaluations: 104
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.027241021220066663
#             Iterations: 10
#             Function evaluations: 95
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.027062983444879275
#             Iterations: 10
#             Function evaluations: 95
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.026970169993682267
#             Iterations: 10
#             Function evaluations: 95
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.026733781796311536
#             Iterations: 10
#             Function evaluations: 96
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.02664385509762899
#             Iterations: 10
#             Function evaluations: 96
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.024375803089062925
#             Iterations: 10
#             Function evaluations: 95
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.023072516178549263
#             Iterations: 10
#             Function evaluations: 95
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1903453172609001e-07
#             Iterations: 14
#             Function evaluations: 132
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.017028610794791583
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.016662753190645564
#             Iterations: 11
#             Function evaluations: 103
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.016463233804037226
#             Iterations: 11
#             Function evaluations: 104
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.29456297679636e-08
#             Iterations: 12
#             Function evaluations: 112
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.875752102472835e-07
#             Iterations: 14
#             Function evaluations: 133
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.088231148294501e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.124643689421676e-08
#             Iterations: 12
#             Function evaluations: 117
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3248916312815357e-07
#             Iterations: 14
#             Function evaluations: 131
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.40920615334249e-09
#             Iterations: 17
#             Function evaluations: 160
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.014283442679717491
#             Iterations: 10
#             Function evaluations: 94
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.014844757692239766
#             Iterations: 10
#             Function evaluations: 95
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.015080714400170009
#             Iterations: 10
#             Function evaluations: 94
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.01498015168637873
#             Iterations: 10
#             Function evaluations: 94
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.015536445094304678
#             Iterations: 11
#             Function evaluations: 104
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.015489660114439335
#             Iterations: 11
#             Function evaluations: 104
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.2060801753395497e-07
#             Iterations: 19
#             Function evaluations: 180
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.058611463397683e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.8475891997287226e-07
#             Iterations: 14
#             Function evaluations: 134
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2010478435909407e-07
#             Iterations: 15
#             Function evaluations: 144
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.0036195799169544e-07
#             Iterations: 16
#             Function evaluations: 153
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.711518563363268e-08
#             Iterations: 17
#             Function evaluations: 162
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.240810002067097e-08
#             Iterations: 18
#             Function evaluations: 170
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.9252784422797736e-07
#             Iterations: 14
#             Function evaluations: 135
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.4246988584090218e-08
#             Iterations: 14
#             Function evaluations: 134
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3450391241053648e-07
#             Iterations: 13
#             Function evaluations: 125
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.434726322929782e-07
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.7580117166442703e-07
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.973832976774312e-07
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.0414987845327804e-07
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.6598123974397127e-07
#             Iterations: 15
#             Function evaluations: 145
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.0674155385568232e-07
#             Iterations: 13
#             Function evaluations: 123
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2456283763169474e-07
#             Iterations: 16
#             Function evaluations: 152
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1765336557573631e-08
#             Iterations: 16
#             Function evaluations: 153
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.7865326764092722e-07
#             Iterations: 17
#             Function evaluations: 162
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.756616320770238e-07
#             Iterations: 17
#             Function evaluations: 161
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.777465809110174e-09
#             Iterations: 14
#             Function evaluations: 133
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.018377253221539e-08
#             Iterations: 15
#             Function evaluations: 142
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 8.486069007712847e-09
#             Iterations: 15
#             Function evaluations: 142
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.660678103059543e-08
#             Iterations: 16
#             Function evaluations: 151
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1064147535538161e-07
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0948268290999745e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0161371217062769e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2457230376278148e-09
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.976802094720822e-10
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.2708189094249614e-09
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.44818536151389e-09
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.049918506370681e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.3555724179196275e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.908878745927905e-09
#             Iterations: 13
#             Function evaluations: 123
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.69374695198753e-08
#             Iterations: 13
#             Function evaluations: 125
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.0991201857827708e-08
#             Iterations: 15
#             Function evaluations: 146
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.8696159060053923e-07
#             Iterations: 16
#             Function evaluations: 154
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3159132379051794e-07
#             Iterations: 16
#             Function evaluations: 154
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.9922585701351068e-08
#             Iterations: 15
#             Function evaluations: 145
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.824232919727907e-07
#             Iterations: 15
#             Function evaluations: 144
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.8114432860054503e-07
#             Iterations: 15
#             Function evaluations: 145
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.630610216659461e-07
#             Iterations: 16
#             Function evaluations: 153
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.8536744844730434e-07
#             Iterations: 17
#             Function evaluations: 161
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0420451860283704e-08
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.146173704279018e-08
#             Iterations: 11
#             Function evaluations: 108
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.5815769896093367e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.764759830303827e-08
#             Iterations: 13
#             Function evaluations: 124
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.3039473222225795e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.5817825243517698e-07
#             Iterations: 13
#             Function evaluations: 125
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9411413280586485e-07
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.7219598096874875e-07
#             Iterations: 10
#             Function evaluations: 99
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4366469349391003e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3386015340886485e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.6840953553063233e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.867192409755422e-07
#             Iterations: 12
#             Function evaluations: 116
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.7511865387421156e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.566994552159709e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.560206741250634e-08
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.533385027759158e-08
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.249720846829002e-08
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.706498241066225e-07
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.8614676664558556e-07
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 8.253081473143407e-07
#             Iterations: 10
#             Function evaluations: 98
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.8235557455607005e-07
#             Iterations: 11
#             Function evaluations: 107
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.1124817210439e-08
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.4064712890552755e-07
#             Iterations: 13
#             Function evaluations: 123
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.188094557965115e-07
#             Iterations: 12
#             Function evaluations: 115
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.125642219425865e-07
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.478081087364892e-08
#             Iterations: 12
#             Function evaluations: 114
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.7112219728081547e-07
#             Iterations: 11
#             Function evaluations: 105
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.858306246510408e-07
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4107499020644427e-07
#             Iterations: 10
#             Function evaluations: 96
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.891628533710134e-07
# ...
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4572981772364126e-08
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.89039566304731e-09
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.093509528347248e-09
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0013524493076783e-07
#             Iterations: 8
#             Function evaluations: 80
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.482122619995827e-07
#             Iterations: 9
#             Function evaluations: 88
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.472438319803121e-07
#             Iterations: 9
#             Function evaluations: 88
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.4076517349373954e-07
#             Iterations: 9
#             Function evaluations: 88
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.61213532274478e-07
#             Iterations: 9
#             Function evaluations: 88
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9517050466139494e-09
#             Iterations: 9
#             Function evaluations: 89
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.779661632197964e-07
#             Iterations: 9
#             Function evaluations: 88
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.6140897072466447e-09
#             Iterations: 9
#             Function evaluations: 89
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.0308155327763786e-09
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0464370840347583e-08
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.9553846737020734e-08
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.842314774613354e-08
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.434484734923726e-08
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.572175881194755e-08
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.022443889463374e-09
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.6682790929818668e-09
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.786678685315997e-09
#             Iterations: 10
#             Function evaluations: 97
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.6169697984519224e-08
#             Iterations: 11
#             Function evaluations: 106
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.1707145465552576e-10
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1597494036737155e-07
#             Iterations: 10
#             Function evaluations: 96
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.050065047359572e-09
#             Iterations: 12
#             Function evaluations: 113
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.8000681954132646e-07
#             Iterations: 9
#             Function evaluations: 88
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.914199988045055e-08
#             Iterations: 11
#             Function evaluations: 104
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 8.388761912305984e-08
#             Iterations: 12
#             Function evaluations: 111
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.9574738092706508e-07
#             Iterations: 8
#             Function evaluations: 78
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1837928364595518e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.6065724460661796e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1931193051668616e-07
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.3039721411128184e-08
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.8876945111377974e-08
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.238648249368579e-08
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4224650825101568e-08
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9146420857205942e-08
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.995210096819728e-10
#             Iterations: 6
#             Function evaluations: 61
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.009672633831431e-09
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.0267049278451695e-09
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.551261156609648e-07
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.460968830830281e-08
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.4944888146750407e-07
#             Iterations: 8
#             Function evaluations: 76
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.833886398676051e-07
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.443265010892073e-07
#             Iterations: 7
#             Function evaluations: 67
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.426888187860753e-07
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.006948642077804e-07
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2231143875711364e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.153367993367321e-08
#             Iterations: 7
#             Function evaluations: 67
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3136006007979465e-08
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.435955228031357e-08
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2988357416293283e-07
#             Iterations: 8
#             Function evaluations: 76
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.145557629256118e-08
#             Iterations: 8
#             Function evaluations: 76
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.967160066808579e-08
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.455287670111504e-07
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2197621716105254e-07
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.995543249018431e-07
#             Iterations: 7
#             Function evaluations: 68
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.68091720294274e-08
#             Iterations: 8
#             Function evaluations: 78
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.475055239772763e-07
#             Iterations: 5
#             Function evaluations: 50
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 8.31651967825863e-08
#             Iterations: 8
#             Function evaluations: 78
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.426563387609546e-08
#             Iterations: 9
#             Function evaluations: 86
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1400962269437225e-07
#             Iterations: 9
#             Function evaluations: 85
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.2547662667655254e-08
#             Iterations: 10
#             Function evaluations: 93
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.567552690263535e-08
#             Iterations: 8
#             Function evaluations: 77
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.468260863497002e-07
#             Iterations: 6
#             Function evaluations: 60
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.9689959200847665e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.993340030121323e-09
#             Iterations: 8
#             Function evaluations: 78
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.06331459530539e-09
#             Iterations: 8
#             Function evaluations: 78
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.65101905802844e-09
#             Iterations: 8
#             Function evaluations: 78
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.13248138344101e-09
#             Iterations: 9
#             Function evaluations: 86
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1130068905503208e-07
#             Iterations: 6
#             Function evaluations: 61
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1197214973726843e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.208275496877026e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.885771335911024e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.439577064282691e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.1722126856625394e-07
#             Iterations: 7
#             Function evaluations: 69
#             Gradient evaluations: 7

# %%
# Equal risk contribution factor weighting strategy with monthly rebalancing
df_erc['Date'] = corr_eq.index[59:] # start date 1968-06-01, end date: 2018-03-01
df_erc.set_index('Date', inplace=True)
df_erc.head() # use df_erc.sum(axis=1) to check if all weights sum to 1
# Out:
#            12-1 Momentum Book-to-Price Cash-to-Price Dividend Yield  \
# Date
# 1968-06-01      0.248627      0.112261      0.132397       0.132183
# 1968-07-01      0.250056      0.108092      0.127968          0.127
# 1968-08-01       0.24861      0.108018      0.127614       0.128077
# 1968-09-01      0.248067      0.107864      0.127917        0.12789
# 1968-10-01       0.25226      0.107637      0.129111       0.125962
#
#            Investment Prior Month Return Profitability
# Date
# 1968-06-01   0.118634           0.255897  -2.93975e-16
# 1968-07-01   0.118966           0.267919  -5.11221e-16
# 1968-08-01   0.117736           0.269944  -1.57612e-14
# 1968-09-01   0.117323           0.270939   1.20125e-16
# 1968-10-01   0.117615           0.267415  -3.96628e-16

# %% [markdown]
# c) Plot the monthly factor weights over time and evaluate the strategy performance against the static equally weighted factor portfolio. Comment on your results. (Hint: Use Matlab’s fmincon function as detailed below)

# %%
sns.set_context('talk') # set plot to a approriate view & fontsize
df_erc.plot(figsize=(20,10), title='Factor Weights over Time')

# %%
# Strategy performance of ERC vs EW portfolios

# ERC cumulative returns
erc_portfolio = df_erc*corr_eq[59:] # weights * returns starting from 1968-06-01
erc_portfolio = erc_portfolio.sum(axis=1).cumsum() # sum all factor returns for each month. Cumsum for the entire period

# EW cumulative returns 
eq_weighted_portfolio = corr_eq[59:]*1/7
eq_weighted_portfolio = eq_weighted_portfolio.sum(axis=1).cumsum()
strat_perform_1 = pd.DataFrame({'Equal Risk Contribution': erc_portfolio, 'Equally Weighted': eq_weighted_portfolio})

sns.set_context('talk')
strat_perform_1.plot(figsize=(20,10), title='ERC versus EW Cumulative Returns')

# %% [markdown]
# ### Task 3
# Using different lookback periods of 1,12 and 36 months to determine factor persistence, build adaptive multi-factor models that appropriately reflect your view on each factor. For example, you may want to consider a factor weighting approach such that the factor allocation is proportional to the historical Sharpe ratio for a given lookback period. Comment on your results.

# %%
factor_names = corr_eq.columns.values
factor_persist = [pd.DataFrame({corr_eq.columns.values[i]: corr_eq[59:].iloc[:, i].cumsum(), '*Equal Factor Weight': eq_weighted_portfolio}) for i in range(7)]

fig, axs = plt.subplots(4,2,figsize=(15,23))
fig.delaxes(axs[-1, -1])
factor_persist[0].plot(ax=axs[0,0], title= factor_names[0] + ' Vs Equal Factor Weight')
factor_persist[1].plot(ax=axs[0,1], title= factor_names[1] + ' Vs Equal Factor Weight')
factor_persist[2].plot(ax=axs[1,0], title= factor_names[2] + ' Vs Equal Factor Weight')
factor_persist[3].plot(ax=axs[1,1], title= factor_names[3] + ' Vs Equal Factor Weight')
factor_persist[4].plot(ax=axs[2,0], title= factor_names[4] + ' Vs Equal Factor Weight')
factor_persist[5].plot(ax=axs[2,1], title= factor_names[5] + ' Vs Equal Factor Weight')
factor_persist[6].plot(ax=axs[3,0], title= factor_names[6] + ' Vs Equal Factor Weight')
plt.show()

# %%
from sklearn.decomposition import PCA

# %%
X = np.asarray(corr_eq)
[n,m] = X.shape
print('The number of timestamps is {}.'.format(n))
print('The number of factors is {}.'.format(m))
# Out:
# The number of timestamps is 657.
# The number of factors is 7.

# %%
pca = PCA(n_components=3) # number of principal components
pca.fit(X)

percentage =  pca.explained_variance_ratio_
percentage_cum = np.cumsum(percentage)
print('{0:.2f}% of the variance is explained by the first 2 PCs'.format(percentage_cum[-1]*100)) 

pca_components = pca.components_
# Out:
# 82.63% of the variance is explained by the first 2 PCs

# %%
xx = np.arange(1,len(percentage)+1,1)

plt.subplot(1, 2, 1)
plt.bar(xx, percentage*100, align = "center")
plt.title('Contribution of principal components',fontsize = 16)
plt.xlabel('principal components',fontsize = 16)
plt.ylabel('percentage',fontsize = 16)
plt.xticks(xx,fontsize = 16) 
plt.yticks(fontsize = 16)
plt.xlim([0, 3+1])

plt.subplot(1, 2, 2)
plt.plot(xx, percentage_cum*100,'ro-')
plt.xlabel('principal components',fontsize = 16)
plt.ylabel('percentage',fontsize = 16)
plt.title('Cumulative contribution of principal components',fontsize = 16)
plt.xticks(xx,fontsize = 16) 
plt.yticks(fontsize = 16)
plt.xlim([1, 3])
plt.ylim([50,100]);
